# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import CategoricalNB

# %% [markdown]
# Teste usando a tabela sem alteração:

# %%
dados = pd.read_csv('data.csv', sep=';')
dados.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# 2                           122.0            1                      37
# 3                           122.0            1                      38
# 4                           100.0            1                      37
#
#    Father's qualification  ...  Curricular units 2nd sem (credited)  \
# 0                      12  ...                                    0
# 1                       3  ...                                    0
# 2                      37  ...                                    0
# 3                      37  ...                                    0
# 4                      38  ...                                    0
#
#    Curricular units 2nd sem (enrolled)  \
# 0                                    0
# 1                                    6
# 2                                    6
# 3                                    6
# 4                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate   GDP    Target
# 0             1.4  1.74   Dropout
# 1            -0.3  0.79  Graduate
# 2             1.4  1.74   Dropout
# 3            -0.8 -3.12  Graduate
# 4            -0.3  0.79  Graduate
#
# [5 rows x 37 columns]

# %%
#Arrumando GDP e Inflation Rate para serem sempre positivos
for a in range(len(dados.index)):
  dados.GDP[dados.index[a]] += 10
  dados['Inflation rate'][dados.index[a]] += 10
#Aplicando um filtro para retirar a coluna "Target" que é o nosso objetivo
filter1 = dados[(dados['Target'] != 'Enrolled')]
filter1.drop(['Target'], inplace = True, axis = 1)
# Out:
# <ipython-input-37-c28c660503bb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.GDP[dados.index[a]] += 10
# <ipython-input-37-c28c660503bb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados['Inflation rate'][dados.index[a]] += 10
# <ipython-input-37-c28c660503bb>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter1.drop(['Target'], inplace = True, axis = 1)

# %%
#Separando o objetivo
Y = dados.loc[dados['Target'] != 'Enrolled', 'Target']
Y.head(10)
# Out:
# 0     Dropout
# 1    Graduate
# 2     Dropout
# 3    Graduate
# 4    Graduate
# 5    Graduate
# 6    Graduate
# 7     Dropout
# 8    Graduate
# 9     Dropout
# Name: Target, dtype: object

# %%
#Treinando o modelo
model = CategoricalNB()
model.fit(filter1, Y)
#Accuracy do modelo
acc_train = model.score(filter1, Y)
print(acc_train)
# Out:
# 0.8713498622589532

# %% [markdown]
# Aplicando as categorizações às colunas:

# %%
dados.rename(columns = {'Application mode':'ApplicationMode'}, inplace = True)
dados.rename(columns = {'Previous qualification':'PreviousQualification'}, inplace = True)
# Agrupando dados para melhorar o CategoricalNB
for a in range(4424):
  #Modo de entrada
  if dados.ApplicationMode[a] in [1, 2, 10, 17, 18]: dados.ApplicationMode[a] = 0 #Entrada normal
  elif dados.ApplicationMode[a] in [5, 15, 16, 26]: dados.ApplicationMode[a] = 1 #Entrada especial
  elif dados.ApplicationMode[a] in [27, 42, 43, 51, 57]: dados.ApplicationMode[a] = 2 #Mudança de curso/Transferência
  else: dados.ApplicationMode[a] = 3 #Já tem diploma
  #Previous education
  if dados.PreviousQualification[a] in [2, 3, 4, 5, 6, 39, 40, 42, 43]: dados.PreviousQualification[a] = 0 #Ensino superior
  elif dados.PreviousQualification[a] in [9, 10, 12, 14, 15]: dados.PreviousQualification[a] = 2 #Ensino médio incompleto
  elif dados.PreviousQualification[a] != 1: dados.PreviousQualification[a] = 3 #Fundamental incompleto
# Out:
# <ipython-input-40-01464f29db05>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if dados.ApplicationMode[a] in [1, 2, 10, 17, 18]: dados.ApplicationMode[a] = 0 #Entrada normal
# <ipython-input-40-01464f29db05>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif dados.ApplicationMode[a] in [5, 15, 16, 26]: dados.ApplicationMode[a] = 1 #Entrada especial
# <ipython-input-40-01464f29db05>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dados.ApplicationMode[a] = 3 #Já tem diploma
# <ipython-input-40-01464f29db05>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif dados.PreviousQualification[a] != 1: dados.PreviousQualification[a] = 3 #Fundamental incompleto
# <ipython-input-40-01464f29db05>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if dados.PreviousQualification[a] in [2, 3, 4, 5, 6, 39, 40, 42, 43]: dados.PreviousQualification[a] = 0 #Ensino superior
# <ipython-input-40-01464f29db05>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif dados.ApplicationMode[a] in [27, 42, 43, 51, 57]: dados.ApplicationMode[a] = 2 #Mudança de curso/Transferência
# <ipython-input-40-01464f29db05>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif dados.PreviousQualification[a] in [9, 10, 12, 14, 15]: dados.PreviousQualification[a] = 2 #Ensino médio incompleto

# %%
dados.rename(columns = {'Previous qualification (grade)':'PreviousGrade'}, inplace = True)
# Tornando as variáveis "contínuas" em categorias para facilitar o CatergoricalNB
for a in range(4424):
  if dados.PreviousGrade[a] < 111: #Muito ruim
    dados.PreviousGrade[a] = 0
  elif dados.PreviousGrade[a] < 131: #Ruim
    dados.PreviousGrade[a] = 1
  elif dados.PreviousGrade[a] < 151: #Médio
    dados.PreviousGrade[a] = 2
  elif dados.PreviousGrade[a] < 171: #Bom
    dados.PreviousGrade[a] = 3
  else: dados.PreviousGrade[a] = 4 #Muito bom
# Out:
# <ipython-input-41-daed4730d521>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.PreviousGrade[a] = 1
# <ipython-input-41-daed4730d521>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.PreviousGrade[a] = 3
# <ipython-input-41-daed4730d521>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.PreviousGrade[a] = 0
# <ipython-input-41-daed4730d521>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.PreviousGrade[a] = 2
# <ipython-input-41-daed4730d521>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dados.PreviousGrade[a] = 4 #Muito bom

# %% [markdown]
# Teste após categorização de parâmetros (sem retirar colunas):

# %%
#Aplicando um filtro para retirar a coluna "Target" que é o nosso objetivo
filter2 = dados[(dados['Target'] != 'Enrolled')]
filter2.drop(['Target'], inplace = True, axis = 1)
#Treinando o modelo
model.fit(filter2, Y)
#Accuracy do modelo
acc_train = model.score(filter2, Y)
print(acc_train)
filter2.head()
# Out:
# 0.8727272727272727
# <ipython-input-42-b8f2719b4150>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter2.drop(['Target'], inplace = True, axis = 1)
#    Marital status  ApplicationMode  Application order  Course  \
# 0               1                0                  5     171
# 1               1                1                  1    9254
# 2               1                0                  5    9070
# 3               1                0                  2    9773
# 4               2                3                  1    8014
#
#    Daytime/evening attendance\t  PreviousQualification  PreviousGrade  \
# 0                             1                      1            1.0
# 1                             1                      1            3.0
# 2                             1                      1            1.0
# 3                             1                      1            1.0
# 4                             0                      1            0.0
#
#    Nacionality  Mother's qualification  Father's qualification  ...  \
# 0            1                      19                      12  ...
# 1            1                       1                       3  ...
# 2            1                      37                      37  ...
# 3            1                      38                      37  ...
# 4            1                      37                      38  ...
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  Curricular units 2nd sem (enrolled)  \
# 0                                    0                                    0
# 1                                    0                                    6
# 2                                    0                                    6
# 3                                    0                                    6
# 4                                    0                                    6
#
#    Curricular units 2nd sem (evaluations)  \
# 0                                       0
# 1                                       6
# 2                                       0
# 3                                      10
# 4                                       6
#
#    Curricular units 2nd sem (approved)  Curricular units 2nd sem (grade)  \
# 0                                    0                          0.000000
# 1                                    6                         13.666667
# 2                                    0                          0.000000
# 3                                    5                         12.400000
# 4                                    6                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate    GDP
# 0            11.4  11.74
# 1             9.7  10.79
# 2            11.4  11.74
# 3             9.2   6.88
# 4             9.7  10.79
#
# [5 rows x 36 columns]

# %% [markdown]
# Mudança mais importante (União de duas colunas em uma):

# %%
dados.rename(columns = {'Curricular units 1st sem (enrolled)':'Enrolled1st'}, inplace = True)
dados.rename(columns = {'Curricular units 1st sem (approved)':'Approved1st'}, inplace = True)
dados.rename(columns = {'Curricular units 2nd sem (enrolled)':'Enrolled2nd'}, inplace = True)
dados.rename(columns = {'Curricular units 2nd sem (approved)':'Approved2nd'}, inplace = True)
# Converter as colunas de matrícula/aprovação dos semestres em uma única coluna de proporção entre elas
for a in range(4424):
  if dados.Enrolled1st[a] == 0: dados.Approved1st[a] = 4 #Não se matriculou
  else:
    ratio1st = dados.Approved1st[a] / dados.Enrolled1st[a]
    if (ratio1st > 0.9) & (ratio1st <= 1): dados.Approved1st[a] = 0 #Excelente desempenho
    elif (ratio1st > 0.7) & (ratio1st <= 0.9): dados.Approved1st[a] = 1 #Bom desempenho
    elif (ratio1st > 0.5) & (ratio1st <= 0.7): dados.Approved1st[a] = 2
    else: dados.Approved1st[a] = 3 #Mal desempenho
  if dados.Enrolled2nd[a] == 0: dados.Approved2nd[a] = 4 #Não se matriculou
  else:
    ratio2nd = dados.Approved2nd[a] / dados.Enrolled2nd[a]
    if (ratio2nd > 0.9) & (ratio2nd <= 1): dados.Approved2nd[a] = 0 #Excelente desempenho
    elif (ratio2nd > 0.7) & (ratio2nd <= 0.9): dados.Approved2nd[a] = 1 #Bom desempenho
    elif (ratio2nd > 0.5) & (ratio2nd <= 0.7): dados.Approved2nd[a] = 2 #Médio desempenho
    else: dados.Approved2nd[a] = 3 #Mal desempenho
dados.rename(columns = {'Approved1st':'1st semester performance'}, inplace = True)
dados.rename(columns = {'Approved2nd':'2nd semester performance'}, inplace = True)
dados.drop(['Enrolled1st', 'Enrolled2nd'], inplace = True, axis = 1)
dados.head()
# Out:
# <ipython-input-43-479208742204>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if dados.Enrolled1st[a] == 0: dados.Approved1st[a] = 4 #Não se matriculou
# <ipython-input-43-479208742204>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if dados.Enrolled2nd[a] == 0: dados.Approved2nd[a] = 4 #Não se matriculou
# <ipython-input-43-479208742204>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if (ratio1st > 0.9) & (ratio1st <= 1): dados.Approved1st[a] = 0 #Excelente desempenho
# <ipython-input-43-479208742204>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if (ratio2nd > 0.9) & (ratio2nd <= 1): dados.Approved2nd[a] = 0 #Excelente desempenho
# <ipython-input-43-479208742204>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dados.Approved1st[a] = 3 #Mal desempenho
# <ipython-input-43-479208742204>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   else: dados.Approved2nd[a] = 3 #Mal desempenho
# <ipython-input-43-479208742204>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif (ratio2nd > 0.7) & (ratio2nd <= 0.9): dados.Approved2nd[a] = 1 #Bom desempenho
# <ipython-input-43-479208742204>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif (ratio1st > 0.7) & (ratio1st <= 0.9): dados.Approved1st[a] = 1 #Bom desempenho
# <ipython-input-43-479208742204>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif (ratio2nd > 0.5) & (ratio2nd <= 0.7): dados.Approved2nd[a] = 2 #Médio desempenho
# <ipython-input-43-479208742204>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elif (ratio1st > 0.5) & (ratio1st <= 0.7): dados.Approved1st[a] = 2
#    Marital status  ApplicationMode  Application order  Course  \
# 0               1                0                  5     171
# 1               1                1                  1    9254
# 2               1                0                  5    9070
# 3               1                0                  2    9773
# 4               2                3                  1    8014
#
#    Daytime/evening attendance\t  PreviousQualification  PreviousGrade  \
# 0                             1                      1            1.0
# 1                             1                      1            3.0
# 2                             1                      1            1.0
# 3                             1                      1            1.0
# 4                             0                      1            0.0
#
#    Nacionality  Mother's qualification  Father's qualification  ...  \
# 0            1                      19                      12  ...
# 1            1                       1                       3  ...
# 2            1                      37                      37  ...
# 3            1                      38                      37  ...
# 4            1                      37                      38  ...
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
#
#    Curricular units 2nd sem (evaluations)  2nd semester performance  \
# 0                                       0                         4
# 1                                       6                         0
# 2                                       0                         3
# 3                                      10                         1
# 4                                       6                         0
#
#    Curricular units 2nd sem (grade)  \
# 0                          0.000000
# 1                         13.666667
# 2                          0.000000
# 3                         12.400000
# 4                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate    GDP    Target
# 0            11.4  11.74   Dropout
# 1             9.7  10.79  Graduate
# 2            11.4  11.74   Dropout
# 3             9.2   6.88  Graduate
# 4             9.7  10.79  Graduate
#
# [5 rows x 35 columns]

# %% [markdown]
# Teste após a mudança mais importante (sem retirar colunas):

# %%
#Aplicando um filtro para retirar a coluna "Target" que é o nosso objetivo
filter3 = dados[(dados['Target'] != 'Enrolled')]
filter3.drop(['Target'], inplace = True, axis = 1)
#Treinando o modelo
model.fit(filter3, Y)
#Accuracy do modelo
acc_train = model.score(filter3, Y)
print(acc_train)
filter3.head()
# Out:
# 0.8928374655647383
# <ipython-input-44-75e290eb40ed>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter3.drop(['Target'], inplace = True, axis = 1)
#    Marital status  ApplicationMode  Application order  Course  \
# 0               1                0                  5     171
# 1               1                1                  1    9254
# 2               1                0                  5    9070
# 3               1                0                  2    9773
# 4               2                3                  1    8014
#
#    Daytime/evening attendance\t  PreviousQualification  PreviousGrade  \
# 0                             1                      1            1.0
# 1                             1                      1            3.0
# 2                             1                      1            1.0
# 3                             1                      1            1.0
# 4                             0                      1            0.0
#
#    Nacionality  Mother's qualification  Father's qualification  ...  \
# 0            1                      19                      12  ...
# 1            1                       1                       3  ...
# 2            1                      37                      37  ...
# 3            1                      38                      37  ...
# 4            1                      37                      38  ...
#
#    Curricular units 1st sem (grade)  \
# 0                          0.000000
# 1                         14.000000
# 2                          0.000000
# 3                         13.428571
# 4                         12.333333
#
#    Curricular units 1st sem (without evaluations)  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
#
#    Curricular units 2nd sem (credited)  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
#
#    Curricular units 2nd sem (evaluations)  2nd semester performance  \
# 0                                       0                         4
# 1                                       6                         0
# 2                                       0                         3
# 3                                      10                         1
# 4                                       6                         0
#
#    Curricular units 2nd sem (grade)  \
# 0                          0.000000
# 1                         13.666667
# 2                          0.000000
# 3                         12.400000
# 4                         13.000000
#
#    Curricular units 2nd sem (without evaluations)  Unemployment rate  \
# 0                                               0               10.8
# 1                                               0               13.9
# 2                                               0               10.8
# 3                                               0                9.4
# 4                                               0               13.9
#
#    Inflation rate    GDP
# 0            11.4  11.74
# 1             9.7  10.79
# 2            11.4  11.74
# 3             9.2   6.88
# 4             9.7  10.79
#
# [5 rows x 34 columns]

# %% [markdown]
# Teste final retirando colunas e usando as alterações dos dados:

# %%
#Aplicando um filtro para manter apenas os atributos desejados
filter = dados[(dados['Target'] != 'Enrolled')]
filter.drop(['Nacionality', 'Marital status', 'Application order', 'Admission grade', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'GDP', 'Displaced', 'Scholarship holder', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Inflation rate', 'Unemployment rate', 'Target'], inplace=True, axis=1)
#Treinando o modelo
model.fit(filter, Y)
#Accuracy do modelo
acc_train = model.score(filter, Y)
print(acc_train)
filter.head(10)
# Out:
# 0.9016528925619834
# <ipython-input-45-72e811ac6ea3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter.drop(['Nacionality', 'Marital status', 'Application order', 'Admission grade', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'GDP', 'Displaced', 'Scholarship holder', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Inflation rate', 'Unemployment rate', 'Target'], inplace=True, axis=1)
#    ApplicationMode  Course  Daytime/evening attendance\t  \
# 0                0     171                             1
# 1                1    9254                             1
# 2                0    9070                             1
# 3                0    9773                             1
# 4                3    8014                             0
# 5                3    9991                             0
# 6                0    9500                             1
# 7                0    9254                             1
# 8                0    9238                             1
# 9                0    9238                             1
#
#    PreviousQualification  PreviousGrade  Educational special needs  Debtor  \
# 0                      1            1.0                          0       0
# 1                      1            3.0                          0       0
# 2                      1            1.0                          0       0
# 3                      1            1.0                          0       0
# 4                      1            0.0                          0       0
# 5                      3            2.0                          0       1
# 6                      1            2.0                          0       0
# 7                      1            1.0                          0       0
# 8                      1            2.0                          0       0
# 9                      1            2.0                          0       1
#
#    Tuition fees up to date  Gender  Age at enrollment  \
# 0                        1       1                 20
# 1                        0       1                 19
# 2                        0       1                 19
# 3                        1       0                 20
# 4                        1       0                 45
# 5                        1       1                 50
# 6                        1       0                 18
# 7                        0       1                 22
# 8                        1       0                 21
# 9                        0       0                 18
#
#    1st semester performance  2nd semester performance
# 0                         4                         4
# 1                         0                         0
# 2                         3                         3
# 3                         0                         1
# 4                         1                         0
# 5                         0                         0
# 6                         0                         0
# 7                         3                         3
# 8                         0                         0
# 9                         1                         3

# %%
#Aplicando o modelo
teste = dados[(dados['Target'] == 'Enrolled')]
teste.drop(['Nacionality', 'Marital status', 'Application order', 'Admission grade', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'GDP', 'Displaced', 'Scholarship holder', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Inflation rate', 'Unemployment rate', 'Target'], inplace=True, axis=1)
pred_classes = model.predict(teste)
teste.insert(loc = 0, column = 'Target', value = pred_classes)
show = teste
print(pred_classes[0:10])
show.head(10)
# Out:
# ['Dropout' 'Graduate' 'Graduate' 'Graduate' 'Graduate' 'Graduate'
#  'Graduate' 'Dropout' 'Dropout' 'Graduate']
# <ipython-input-46-50ff26f3b567>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teste.drop(['Nacionality', 'Marital status', 'Application order', 'Admission grade', "Mother's qualification", "Father's qualification", "Mother's occupation", "Father's occupation", 'GDP', 'Displaced', 'Scholarship holder', 'International', 'Curricular units 1st sem (credited)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (grade)', 'Curricular units 1st sem (without evaluations)', 'Curricular units 2nd sem (credited)', 'Curricular units 2nd sem (evaluations)', 'Curricular units 2nd sem (grade)', 'Curricular units 2nd sem (without evaluations)', 'Inflation rate', 'Unemployment rate', 'Target'], inplace=True, axis=1)
#       Target  ApplicationMode  Course  Daytime/evening attendance\t  \
# 16   Dropout                0    9238                             1
# 19  Graduate                0    9853                             1
# 21  Graduate                0    9556                             1
# 25  Graduate                0    9238                             1
# 27  Graduate                0    9085                             1
# 29  Graduate                0    9500                             1
# 30  Graduate                3    9003                             1
# 32   Dropout                0    9147                             1
# 45   Dropout                0    9991                             0
# 51  Graduate                0    9500                             1
#
#     PreviousQualification  PreviousGrade  Educational special needs  Debtor  \
# 16                      1            2.0                          0       0
# 19                      1            2.0                          0       0
# 21                      1            1.0                          0       0
# 25                      1            3.0                          0       1
# 27                      1            2.0                          0       0
# 29                      1            1.0                          0       0
# 30                      0            2.0                          0       0
# 32                      1            2.0                          0       0
# 45                      1            3.0                          0       0
# 51                      1            2.0                          0       0
#
#     Tuition fees up to date  Gender  Age at enrollment  \
# 16                        1       0                 18
# 19                        1       0                 18
# 21                        1       0                 20
# 25                        1       0                 18
# 27                        1       0                 18
# 29                        1       1                 19
# 30                        1       1                 21
# 32                        0       1                 18
# 45                        1       0                 24
# 51                        1       0                 19
#
#     1st semester performance  2nd semester performance
# 16                         3                         3
# 19                         1                         1
# 21                         0                         0
# 25                         1                         2
# 27                         0                         1
# 29                         1                         1
# 30                         1                         1
# 32                         2                         3
# 45                         3                         2
# 51                         1                         1

# %%
#Porcentagem de graduados
b = 0
c = 0
for a in range(len(show.index)):
  if show.Target[show.index[a]] == 'Graduate':
    b += 1
  c += 1
print(100*b/c)
# Out:
# 55.2896725440806

# %%
#Tabela dos desistentes
printar = show[(show['Target'] == 'Dropout')]
printar.head(len(printar.index))
# Out:
#        Target  ApplicationMode  Course  Daytime/evening attendance\t  \
# 16    Dropout                0    9238                             1
# 32    Dropout                0    9147                             1
# 45    Dropout                0    9991                             0
# 52    Dropout                0    9773                             1
# 63    Dropout                0    9070                             1
# ...       ...              ...     ...                           ...
# 4354  Dropout                3    9991                             0
# 4381  Dropout                0    9238                             1
# 4397  Dropout                1    9853                             1
# 4406  Dropout                0    9070                             1
# 4413  Dropout                2      33                             1
#
#       PreviousQualification  PreviousGrade  Educational special needs  Debtor  \
# 16                        1            2.0                          0       0
# 32                        1            2.0                          0       0
# 45                        1            3.0                          0       0
# 52                        1            1.0                          0       0
# 63                        1            1.0                          0       0
# ...                     ...            ...                        ...     ...
# 4354                      1            2.0                          0       0
# 4381                      1            2.0                          0       0
# 4397                      1            1.0                          0       0
# 4406                      1            2.0                          0       0
# 4413                      1            2.0                          0       0
#
#       Tuition fees up to date  Gender  Age at enrollment  \
# 16                          1       0                 18
# 32                          0       1                 18
# 45                          1       0                 24
# 52                          1       0                 20
# 63                          1       1                 19
# ...                       ...     ...                ...
# 4354                        1       0                 30
# 4381                        1       0                 20
# 4397                        1       0                 21
# 4406                        1       1                 20
# 4413                        1       1                 25
#
#       1st semester performance  2nd semester performance
# 16                           3                         3
# 32                           2                         3
# 45                           3                         2
# 52                           2                         3
# 63                           1                         3
# ...                        ...                       ...
# 4354                         2                         1
# 4381                         3                         3
# 4397                         1                         3
# 4406                         2                         3
# 4413                         3                         3
#
# [355 rows x 13 columns]

# %%
#Tabela dos graduados
printar = show[(show['Target'] == 'Graduate')]
printar.head(len(printar.index))
# Out:
#         Target  ApplicationMode  Course  Daytime/evening attendance\t  \
# 19    Graduate                0    9853                             1
# 21    Graduate                0    9556                             1
# 25    Graduate                0    9238                             1
# 27    Graduate                0    9085                             1
# 29    Graduate                0    9500                             1
# ...        ...              ...     ...                           ...
# 4373  Graduate                0    9238                             1
# 4391  Graduate                3    9500                             1
# 4392  Graduate                0    9147                             1
# 4402  Graduate                0    9853                             1
# 4412  Graduate                2    9070                             1
#
#       PreviousQualification  PreviousGrade  Educational special needs  Debtor  \
# 19                        1            2.0                          0       0
# 21                        1            1.0                          0       0
# 25                        1            3.0                          0       1
# 27                        1            2.0                          0       0
# 29                        1            1.0                          0       0
# ...                     ...            ...                        ...     ...
# 4373                      1            1.0                          0       0
# 4391                      0            1.0                          0       0
# 4392                      1            3.0                          0       0
# 4402                      1            3.0                          0       0
# 4412                      1            1.0                          0       0
#
#       Tuition fees up to date  Gender  Age at enrollment  \
# 19                          1       0                 18
# 21                          1       0                 20
# 25                          1       0                 18
# 27                          1       0                 18
# 29                          1       1                 19
# ...                       ...     ...                ...
# 4373                        1       0                 19
# 4391                        1       0                 32
# 4392                        1       0                 18
# 4402                        1       1                 18
# 4412                        1       1                 19
#
#       1st semester performance  2nd semester performance
# 19                           1                         1
# 21                           0                         0
# 25                           1                         2
# 27                           0                         1
# 29                           1                         1
# ...                        ...                       ...
# 4373                         3                         0
# 4391                         0                         1
# 4392                         1                         0
# 4402                         1                         0
# 4412                         2                         1
#
# [439 rows x 13 columns]
